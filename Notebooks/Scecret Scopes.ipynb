# %%
dbutils.secrets.help()
# Out:
# <div class = "ansiout">
# Provides utilities for leveraging secrets within notebooks.
# Databricks documentation for more info.
#     <h3></h3><b>get(scope: String, key: String): String</b> -> Gets the string representation of a secret value with scope and key<br /><b>get(catalog: String, schema: String, key: String): String</b> -> Gets the string representation of a unity catalog secret value<br /><b>getBytes(scope: String, key: String): byte[]</b> -> Gets the bytes representation of a secret value with scope and key<br /><b>getBytes(catalog: String, schema: String, key: String): byte[]</b> -> Gets the bytes representation of a unity catalog secret value<br /><b>list(scope: String): Seq</b> -> Lists secret metadata for secrets within a scope<br /><b>list(catalog: String, schema: String): Seq</b> -> Lists secret metadata for unity catalog secrets within a catalog and schema<br /><b>listScopes: Seq</b> -> Lists secret scopes<br /><br /></div>

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='db-scope')]

# %%
dbutils.secrets.list("akv")
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-5015278831618032>, line 1
# ----> 1 dbutils.secrets.list("akv")
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:482, in DBUtils.SecretsHandler.list(self, scope, catalog, schema, *posArgs)
#     478     if not scope:
#     479         raise IllegalArgumentException(errMsgWrongListSecretsArgCombination)
#     481     secrets = self.entry_point.getDbutils().preview().secret(
# --> 482     ).list(  # type: ignore[attr-defined]
#     483         scope)
#     484 elif argCount == 2:
#     485     if len(posArgs) >= 1:
#
# File /databricks/spark/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# ...

# %%
dbutils.secrets.get(scope = "akv", key = "db-password")
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-5015278831618033>, line 1
# ----> 1 dbutils.secrets.get(scope = "akv", key = "db-password")
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:376, in DBUtils.SecretsHandler.get(self, scope, catalog, schema, key, *posArgs)
#     373     scope = argsToPass[0]
#     374     key = argsToPass[1]
#     375     return self.entry_point.getDbutils().preview().secret(
# --> 376     ).get(  # type: ignore[attr-defined]
#     377         scope, key)
#     378 else:
#     379     catalog = argsToPass[0]
#
# File /databricks/spark/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# ...

# %% [markdown]
# Databricks scope commands
# -  databricks secrets list-scopes
# -  databricks secrets create-scope db-scope
# -  databricks secrets put-secret db-scope dbhost --string-value=xyz.com

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='db-scope')]

# %%
dbutils.secrets.list("db-scope")
# Out:
# [SecretMetadata(key='dbhost')]

# %%
dbutils.secrets.get("db-scope", "dbhost")
# Out:
# '[REDACTED]'
