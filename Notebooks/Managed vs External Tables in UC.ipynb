-- %%
-- CREATE TABLE
CREATE TABLE DEV.BRONZE.SALE_MANAGED(
  id STRING,
  name STRING,
  PRICE DECIMAL(10,2),
  QUANTITY INT
);

-- INSERT DATA
INSERT INTO DEV.BRONZE.SALE_MANAGED VALUES ('1','Product1',100.00,100);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
-- CREATE TABLE
CREATE TABLE DEV.BRONZE.SALE_EXTERNAL(
  id STRING,
  name STRING,
  PRICE DECIMAL(10,2),
  QUANTITY INT
)
LOCATION 'abfss://data@learndatabrickssg.dfs.core.windows.net/adb/ext_tables/sale_external'
;

-- INSERT DATA
INSERT INTO DEV.BRONZE.SALE_EXTERNAL VALUES ('1','Product1',100.00,100);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
DESCRIBE EXTENDED DEV.BRONZE.SALE_MANAGED
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
DESCRIBE EXTENDED DEV.BRONZE.SALE_EXTERNAL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
DROP TABLE DEV.BRONZE.SALE_MANAGED

-- %%
USE CATALOG DEV;

SHOW TABLES DROPPED IN BRONZE;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
-- This helps to get back the table, in case if deleted by mistake in 7 days
UNDROP TABLE DEV.BRONZE.SALE_MANAGED
